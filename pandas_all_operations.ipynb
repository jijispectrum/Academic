# %%
import pandas as pd

df = pd.read_csv('data(1).csv')

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df1 = pd.DataFrame(data)

print(df1)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df.info()#details about data #rows=164,columns=4,data types of each column and check null values of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
#The info() method also tells us how many Non-Null values there are present in each column, and in our data set it seems like there are 164 of 169 Non-Null values in the "Calories" column.

#Which means that there are 5 rows with no value at all, in the "Calories" column, for whatever reason.

#Empty values, or Null values, can be bad when analyzing data, and you should consider removing rows with empty values.

# %%
df.dropna(inplace = True)#remove null values

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
import pandas as pd

df2 = pd.read_csv('data(1).csv')

# %%
print(df2.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df2.fillna(130, inplace = True) #The fillna() method allows us to replace empty cells with a value:

# %%
print(df2.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     130.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

df3 = pd.read_csv('data(1).csv')

# %%
print(df3.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df3["Calories"].fillna(140, inplace = True) #Replace NULL values in the "Calories" columns with the number 140:

# %%
print(df3.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     140.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

df4 = pd.read_csv('data(1).csv')

# %%
print(df4.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
x = df4["Calories"].mean()

df4["Calories"].fillna(x, inplace = True) #Calculate the MEAN, and replace any empty values with it:

# %%
print(df4.to_string())
# Out:
#      Duration  Pulse  Maxpulse     Calories
# 0          60    110       130   409.100000
# 1          60    117       145   479.000000
# 2          60    103       135   340.000000
# 3          45    109       175   282.400000
# 4          45    117       148   406.000000
# 5          60    102       127   300.000000
# 6          60    110       136   374.000000
# 7          45    104       134   253.300000
# 8          30    109       133   195.100000
# 9          60     98       124   269.000000
# 10         60    103       147   329.300000
# 11         60    100       120   250.700000
# 12         60    106       128   345.300000
# 13         60    104       132   379.300000
# 14         60     98       123   275.000000
# 15         60     98       120   215.200000
# 16         60    100       120   300.000000
# 17         45     90       112   375.790244
# 18         60    103       123   323.000000
# 19         45     97       125   243.000000
# ...

# %%
x = df4["Calories"].median()

df4["Calories"].fillna(x, inplace = True)

# %%
x = df4["Calories"].mode()[0]

df4["Calories"].fillna(x, inplace = True)

# %%
#manipulations

# %%
import pandas as pd
 
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
 
df5 = pd.DataFrame(data)
print(df5)
# Out:
#      Name  Height Qualification
# 0     Jai     5.1           Msc
# 1  Princi     6.2            MA
# 2  Gaurav     5.1           Msc
# 3    Anuj     5.2           Msc

# %%
# Using DataFrame.insert() to add a column
df5.insert(2, "Age", [21, 23, 24, 21], True)

# %%
df5
# Out:
#      Name  Height  Age Qualification
# 0     Jai     5.1   21           Msc
# 1  Princi     6.2   23            MA
# 2  Gaurav     5.1   24           Msc
# 3    Anuj     5.2   21           Msc

# %%
df5 = df5.assign(address=['Delhi', 'Bangalore', 'Chennai', 'Patna'])

# %% [markdown]
# #####

# %%
df5
# Out:
#      Name  Height  Age Qualification    address
# 0     Jai     5.1   21           Msc      Delhi
# 1  Princi     6.2   23            MA  Bangalore
# 2  Gaurav     5.1   24           Msc    Chennai
# 3    Anuj     5.2   21           Msc      Patna

# %%
Mark = [20,45,38,30]
 
# Using 'Address' as the column name
# and equating it to the list
df5['Mark'] = Mark
 
print(df5)
# Out:
#      Name  Height  Age Qualification    address  Mark
# 0     Jai     5.1   21           Msc      Delhi    20
# 1  Princi     6.2   23            MA  Bangalore    45
# 2  Gaurav     5.1   24           Msc    Chennai    38
# 3    Anuj     5.2   21           Msc      Patna    30

# %%
# Create the list of new column values
Weight=[45,55,35,60]
 
# Add the new column using loc
df5.loc[:, "Weight"] = Weight
 
print(df5)
# Out:
#      Name  Height  Age Qualification    address  Mark  Weight
# 0     Jai     5.1   21           Msc      Delhi    20      45
# 1  Princi     6.2   23            MA  Bangalore    45      55
# 2  Gaurav     5.1   24           Msc    Chennai    38      35
# 3    Anuj     5.2   21           Msc      Patna    30      60

# %%
#operations,delete,rows/columns using dropna()

# %%
import pandas as pd
 
# making data frame from csv file
data1 = pd.read_csv("nba.csv", index_col="Name")
print(data1.head(5))
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
# dropping passed values
data1.drop(["Avery Bradley", "John Holland", "R.J. Hunter"], inplace = True)

# display
print(data1)
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0   238.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                  College      Salary
# Name
# Jae Crowder    Marquette   6796117.0
# Jonas Jerebko        NaN   5000000.0
# ...

# %%
# dropping passed columns
data1.drop(["Team", "Weight"], axis = 1, inplace = True)

# display
print(data1.head())
# Out:
#                Number Position   Age Height    College      Salary
# Name
# Jae Crowder      99.0       SF  25.0    6-6  Marquette   6796117.0
# Jonas Jerebko     8.0       PF  29.0   6-10        NaN   5000000.0
# Amir Johnson     90.0       PF  29.0    6-9        NaN  12000000.0
# Jordan Mickey    55.0       PF  21.0    6-8        LSU   1170960.0
# Kelly Olynyk     41.0        C  25.0    7-0    Gonzaga   2165160.0

# %%
#Iterate Over Rows with Pandas

# importing pandas as pd
import pandas as pd

# dictionary of lists
dict = {'name': ["aparna", "pankaj", "sudhir", "Geeku"],
		'degree': ["MBA", "BCA", "M.Tech", "MBA"],
		'score': [90, 40, 80, 98]}

# creating a dataframe from a dictionary
df6 = pd.DataFrame(dict)

print(df6)
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
for i, j in df6.iterrows():
    print(i, j)
    print()
# Out:
# 0 name      aparna
# degree       MBA
# score         90
# Name: 0, dtype: object
#
# 1 name      pankaj
# degree       BCA
# score         40
# Name: 1, dtype: object
#
# 2 name      sudhir
# degree    M.Tech
# score         80
# Name: 2, dtype: object
#
# 3 name      Geeku
# degree      MBA
# score        98
# Name: 3, dtype: object

# %%
columns = list(df6)
 
for i in columns:
 
    # printing the third element of the column
    print(df6[i][2])
# Out:
# sudhir
# M.Tech
# 80

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data2 = pd.read_csv("nba.csv")

# sorting data frame by name
data2.sort_values("Name", axis=0, ascending=True,
				inplace=True, na_position='last')

# display
data2
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
#functions
# importing pandas module
import pandas as pd 

# Define a dictionary containing employee data 
data3 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi', 
				'Gaurav', 'Anuj', 'Princi', 'Abhi'], 
		'Age':[27, 24, 22, 32, 
			33, 36, 27, 32], 
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'], 
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA']} 
	

# Convert the dictionary into DataFrame 
df7 = pd.DataFrame(data3)

print(df7)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
# using keys for grouping
# data

df7.groupby('Name').groups
# Out:
# {'Abhi': [7], 'Anuj': [1, 5], 'Gaurav': [4], 'Jai': [0, 2], 'Princi': [3, 6]}

# %%
# iterating an element
# of group containing 
# multiple keys

grp = df7.groupby(['Name', 'Qualification'])
for name, group in grp:
	print(name)
	print(group)
	print()
# Out:
# ('Abhi', 'MA')
#    Name  Age  Address Qualification
# 7  Abhi   32  Aligarh            MA
#
# ('Anuj', 'B.com')
#    Name  Age Address Qualification
# 5  Anuj   36  Kanpur         B.com
#
# ('Anuj', 'MA')
#    Name  Age Address Qualification
# 1  Anuj   24  Kanpur            MA
#
# ('Gaurav', 'B.Tech')
#      Name  Age  Address Qualification
# 4  Gaurav   33  Jaunpur        B.Tech
#
# ('Jai', 'MCA')
#   Name  Age    Address Qualification
# 2  Jai   22  Allahabad           MCA
#
# ('Jai', 'Msc')
#   Name  Age Address Qualification
# 0  Jai   27  Nagpur           Msc
#
# ('Princi', 'Msc')
#      Name  Age    Address Qualification
# 6  Princi   27  Allahabad           Msc
#
# ('Princi', 'Phd')
#      Name  Age  Address Qualification
# 3  Princi   32  Kannuaj           Phd

# %%
# selecting a single group

grp = df7.groupby('Name')
grp.get_group('Jai')
# Out:
#   Name  Age    Address Qualification
# 0  Jai   27     Nagpur           Msc
# 2  Jai   22  Allahabad           MCA

# %%
# selecting object grouped
# on multiple columns

grp = df7.groupby(['Name', 'Qualification'])
grp.get_group(('Jai', 'Msc'))
# Out:
#   Name  Age Address Qualification
# 0  Jai   27  Nagpur           Msc

# %%
# performing aggregation using
# aggregate method
import numpy as np
grp1 = df7.groupby('Name')

grp1.aggregate(np.sum)
# Out:
# /tmp/ipykernel_13662/3026111100.py:6: FutureWarning: The provided callable <function sum at 0x7f9cd00c08b0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   grp1.aggregate(np.sum)
#         Age           Address Qualification
# Name
# Abhi     32           Aligarh            MA
# Anuj     60      KanpurKanpur       MAB.com
# Gaurav   33           Jaunpur        B.Tech
# Jai      49   NagpurAllahabad        MscMCA
# Princi   59  KannuajAllahabad        PhdMsc

# %%
# performing aggregation on
# group containing multiple
# keys
grp1 = df7.groupby(['Name', 'Qualification'])

grp1.aggregate(np.sum)
# Out:
# /tmp/ipykernel_13662/1688512942.py:6: FutureWarning: The provided callable <function sum at 0x7f9cd00c08b0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   grp1.aggregate(np.sum)
#                       Age    Address
# Name   Qualification
# Abhi   MA              32    Aligarh
# Anuj   B.com           36     Kanpur
#        MA              24     Kanpur
# Gaurav B.Tech          33    Jaunpur
# Jai    MCA             22  Allahabad
#        Msc             27     Nagpur
# Princi Msc             27  Allahabad
#        Phd             32    Kannuaj

# %%
# applying a function by passing
# a list of functions

grp = df7.groupby('Name')

grp['Age'].agg([np.sum, np.mean, np.std])
# Out:
# /tmp/ipykernel_13662/1944853345.py:6: FutureWarning: The provided callable <function sum at 0x7f9cd00c08b0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   grp['Age'].agg([np.sum, np.mean, np.std])
# /tmp/ipykernel_13662/1944853345.py:6: FutureWarning: The provided callable <function mean at 0x7f9cd00c5d30> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'mean' instead.
#   grp['Age'].agg([np.sum, np.mean, np.std])
# /tmp/ipykernel_13662/1944853345.py:6: FutureWarning: The provided callable <function std at 0x7f9cd00c5ee0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'std' instead.
#   grp['Age'].agg([np.sum, np.mean, np.std])
#         sum  mean       std
# Name
# ...

# %%
#Grouping rows in pandas
# importing Pandas 
import pandas as pd 

# example dataframe 
example = {'Team':['Arsenal', 'Manchester United', 'Arsenal', 
				'Arsenal', 'Chelsea', 'Manchester United', 
				'Manchester United', 'Chelsea', 'Chelsea', 'Chelsea'], 
					
		'Player':['Ozil', 'Pogba', 'Lucas', 'Aubameyang', 
					'Hazard', 'Mata', 'Lukaku', 'Morata', 
										'Giroud', 'Kante'], 
										
		'Goals':[5, 3, 6, 4, 9, 2, 0, 5, 2, 3] } 

df8 = pd.DataFrame(example) 

print(df8)
# Out:
#                 Team      Player  Goals
# 0            Arsenal        Ozil      5
# 1  Manchester United       Pogba      3
# 2            Arsenal       Lucas      6
# 3            Arsenal  Aubameyang      4
# 4            Chelsea      Hazard      9
# 5  Manchester United        Mata      2
# 6  Manchester United      Lukaku      0
# 7            Chelsea      Morata      5
# 8            Chelsea      Giroud      2
# 9            Chelsea       Kante      3

# %%
total_goals = df8['Goals'].groupby(df8['Team']) 

# printing the means value 
print(total_goals.mean())
# Out:
# Team
# Arsenal              5.000000
# Chelsea              4.750000
# Manchester United    1.666667
# Name: Goals, dtype: float64

# %%
#combining multiple rows
# importing pandas as pd 
import pandas as pd 

# Creating a dictionary 
d = {'id':['1', '2', '3'], 
	'Column 1.1':[14, 15, 16], 
	'Column 1.2':[10, 10, 10], 
	'Column 1.3':[1, 4, 5], 
	'Column 2.1':[1, 2, 3], 
	'Column 2.2':[10, 10, 10], } 

# Converting dictionary into a data-frame 
df = pd.DataFrame(d) 
print(df)
# Out:
#   id  Column 1.1  Column 1.2  Column 1.3  Column 2.1  Column 2.2
# 0  1          14          10           1           1          10
# 1  2          15          10           4           2          10
# 2  3          16          10           5           3          10

# %%
# Creating the groupby dictionary 
groupby_dict = {'Column 1.1':'Column 1', 
				'Column 1.2':'Column 1', 
				'Column 1.3':'Column 1', 
				'Column 2.1':'Column 2', 
				'Column 2.2':'Column 2' } 

# Set the index of df as Column 'id' 
df = df.set_index('id') 

# Groupby the groupby_dict created above 
df = df.groupby(groupby_dict, axis = 1).min() 
print(df)
# Out:
#     Column 1  Column 2
# id
# 1          1         1
# 2          4         2
# 3          5         3
# /tmp/ipykernel_13662/164608934.py:12: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df = df.groupby(groupby_dict, axis = 1).min()

# %%
#merging ,joining

# %%
# importing pandas module
import pandas as pd 
 
# Define a dictionary containing employee data 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
   
# Define a dictionary containing employee data 
data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'], 
        'Age':[17, 14, 12, 52], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
 
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])
 
print(df, "\n\n", df1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
# using ignore_index
res = pd.concat([df, df1], ignore_index=True)
 
res
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons
